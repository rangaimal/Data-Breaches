# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import pylab as pl
import time 
# %matplotlib inline

# %% [markdown]
# # import data

# %%
df = pd.read_excel(r'C:/Users/Acer/Downloads/DataBreaches.xlsx',index_col=0)

# %%
df.head()
# Out:
#                                  alternative_name records_lost  \
# Entity
# NaN                                           NaN          NaN
# US Customs and Border Protection              NaN       100000
# Click2Gov                                     NaN       300000
# SingHealth                                    NaN      1500000
# Quest Diagnostics                             NaN     11900000
#
#                                               YEAR  \
# Entity
# NaN                               year story broke
# US Customs and Border Protection              2019
# Click2Gov                                     2018
# SingHealth                                    2018
# Quest Diagnostics                             2019
#
#                                                                               story  \
# Entity
# NaN                                                                             NaN
# US Customs and Border Protection  June 2019. Photos of travellers' faces and lic...
# Click2Gov                         Dec 2018. Vulnerabilities in Click2Gov, a type...
# SingHealth                        July 2018. Hackers stole personal details of 1...
# Quest Diagnostics                 June 2019. One of the biggest blood testing pr...
#
#                                                                              SECTOR  \
# Entity
# NaN                               web\nhealthcare\napp\nretail\ngaming\ntranspor...
# US Customs and Border Protection                                         government
# Click2Gov                                                                 financial
# SingHealth                                                               healthcare
# Quest Diagnostics                                                        healthcare
#
#                                                                              METHOD  \
# Entity
# NaN                               poor security\nhacked\noops!\nlost device \nin...
# US Customs and Border Protection                                             hacked
# Click2Gov                                                                    hacked
# SingHealth                                                                   hacked
# Quest Diagnostics                                                     poor security
#
#                                  interesting story  \
# Entity
# NaN                                            NaN
# US Customs and Border Protection                 y
# Click2Gov                                      NaN
# SingHealth                                     NaN
# Quest Diagnostics                              NaN
#
#                                                                    DATA_SENSITIVITY  \
# Entity
# NaN                               1. Just email address/Online information \n2 S...
# US Customs and Border Protection                                                  2
# Click2Gov                                                                         3
# SingHealth                                                                        4
# Quest Diagnostics                                                                 4
#
#                                        DISPLAYED RECORDS      source_name  \
# Entity
# NaN                               =IF(C3>100000000,C3,")              NaN
# US Customs and Border Protection                     NaN  Washington Post
# Click2Gov                                            NaN          Fortune
# SingHealth                                           NaN    Straits Times
# Quest Diagnostics                                    NaN         NBC News
#
#                                                                     1st source link  \
# Entity
# NaN                                                                             NaN
# US Customs and Border Protection  https://www.washingtonpost.com/technology/2019...
# Click2Gov                         http://fortune.com/2018/12/18/click2gov-local-...
# SingHealth                        https://www.straitstimes.com/singapore/persona...
# Quest Diagnostics                 https://www.nbcnewyork.com/news/local/Quest-Di...
#
#                                  2nd source link
# Entity
# NaN                                          NaN
# US Customs and Border Protection             NaN
# Click2Gov                                    NaN
# SingHealth                                   NaN
# Quest Diagnostics                            NaN

# %% [markdown]
# # Data description
# # calling describe method

# %%
desc = df.describe()

# %%
desc
# Out:
#        alternative_name  records_lost  YEAR  \
# count               136           338   340
# unique              135           220    18
# top     American Online       4000000  2018
# freq                  2             7    44
#
#                                                     story SECTOR  METHOD  \
# count                                                 339    340     340
# unique                                                338     25       6
# top     Nov 2010. "Hillary Clinton and several thousan...    web  hacked
# freq                                                    2     97     214
#
#        interesting story  DATA_SENSITIVITY  DISPLAYED RECORDS   source_name  \
# count                 69               340                 33           339
# unique                 1                 7                 31           165
# top                    y                 1          100000000  The Register
# freq                  69               108                  3            14
#
#                                           1st source link  \
# count                                                 339
# unique                                                319
# top     https://www.theregister.co.uk/2019/02/11/620_m...
# freq                                                   13
#
#                                           2nd source link
# count                                                  32
# unique                                                 32
# top     http://news.cnet.com/8301-1009_3-57509595-83/u...
# freq                                                    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 340 entries, nan to AOL
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   alternative_name   136 non-null    object
#  1   records_lost       338 non-null    object
#  2   YEAR               340 non-null    object
#  3   story              339 non-null    object
#  4   SECTOR             340 non-null    object
#  5   METHOD             340 non-null    object
#  6   interesting story  69 non-null     object
#  7   DATA_SENSITIVITY   340 non-null    object
#  8   DISPLAYED RECORDS  33 non-null     object
#  9   source_name        339 non-null    object
#  10  1st source link    339 non-null    object
#  11  2nd source link    32 non-null     object
# dtypes: object(12)
# memory usage: 34.5+ KB

# %%
df.dtypes
# Out:
# alternative_name     object
# records_lost         object
# YEAR                 object
# story                object
# SECTOR               object
# METHOD               object
# interesting story    object
# DATA_SENSITIVITY     object
# DISPLAYED RECORDS    object
# source_name          object
# 1st source link      object
# 2nd source link      object
# dtype: object

# %% [markdown]
# # Data Cleasnisng & validation

# %%
#remove null values
df = pd.read_excel(r'C:/Users/Acer/Downloads/DataBreaches.xlsx',index_col=0,na_values=['n/a'] )

# %%
# Remove the columns
df1 = df.drop(columns=['alternative_name', 'interesting story', '1st source link','2nd source link','DISPLAYED RECORDS'], axis=1).sample(100)

# %%
df1.head()
# Out:
#                    records_lost  YEAR  \
# Entity
# TerraCom & YourTel       170000  2013
# Gamigo                  8000000  2012
# Facebook               50000000  2018
# AOL                    92000000  2004
# Panerabread            37000000  2018
#
#                                                                 story  \
# Entity
# TerraCom & YourTel  May 2013. The telecom firms TerraCom and YourT...
# Gamigo              Jul 2012. 4 months after the gaming site Gamig...
# Facebook            Mar 2018. Cambridge Analytica, headed at the t...
# AOL                 Jun 2004. A former America Online software eng...
# Panerabread         Apr 2018. Customer records were available via ...
#
#                       SECTOR         METHOD DATA_SENSITIVITY  \
# Entity
# TerraCom & YourTel  telecoms          oops!                2
# Gamigo                   web         hacked                1
# Facebook                 web         hacked                1
# AOL                      web     inside job                1
# Panerabread           retail  poor security                2
#
#                                 source_name
# Entity
# TerraCom & YourTel       Boing Boing, Wired
# Gamigo                               Forbes
# Facebook                           Guardian
# AOL                                     CNN
# Panerabread         Krebsonsecurity, Medium

# %%
df1.isnull().sum()
# Out:
# records_lost        2
# YEAR                0
# story               1
# SECTOR              0
# METHOD              0
# DATA_SENSITIVITY    0
# source_name         1
# dtype: int64

# %%
import re

# Remove punctuation
df1['story'] = \
df1['story'].map(lambda x: re.sub('[,\.!?]', '', x))

# Print out the first rows of papers
df1['story'].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-136-a3f5ce7dd6ab> in <module>
#       3 # Remove punctuation
#       4 df1['story'] = \
# ----> 5 df1['story'].map(lambda x: re.sub('[,\.!?]', '', x))
#       6
#       7 # Print out the first rows of papers
#
# ~\.conda\envs\tensorflow\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# ~\.conda\envs\tensorflow\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1143
#    1144         # mapper is a function
# -> 1145         new_values = map_f(values, mapper)
#    1146
#    1147         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-136-a3f5ce7dd6ab> in <lambda>(x)
#       3 # Remove punctuation
#       4 df1['story'] = \
# ----> 5 df1['story'].map(lambda x: re.sub('[,\.!?]', '', x))
#       6
#       7 # Print out the first rows of papers
#
# ~\.conda\envs\tensorflow\lib\re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
#     191     a replacement string to be used."""
# --> 192     return _compile(pattern, flags).sub(repl, string, count)
#     193
#     194 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %% [markdown]
# # Check missing info

# %%
missing_info = list(df1.columns[df1.isnull().any()])

# %%
missing_info
# Out:
# []

# %%
for col in missing_info:
    num_missing = df1[df1[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col, 
                                                    num_missing))

# %% [markdown]
# # Check the correlation

# %%
# validate the cloumns using correlation matrix.
# The statistical relationship between two variables is referred to as their correlation.
# correlation coefficient will always be in the range of -1 to 1.
# minus values means negative relationship betwwen two variables.
# 0 implying no correlation.
# Positive correlations imply that as x increases, so does y.

# %%
df1['story']=df1['story'].astype('category').cat.codes
df1['SECTOR']=df1['SECTOR'].astype('category').cat.codes
df1['METHOD']=df1['METHOD'].astype('category').cat.codes
df1['source_name']=df1['source_name'].astype('category').cat.codes
df1['records_lost']=df1['records_lost'].astype('category').cat.codes
df1['YEAR']=df1['YEAR'].astype('category').cat.codes
df1['DATA_SENSITIVITY']=df1['DATA_SENSITIVITY'].astype('category').cat.codes
df1.corr()
# Out:
#                   records_lost      YEAR     story    SECTOR    METHOD  \
# records_lost          1.000000  0.182034  0.131797  0.149519 -0.040094
# YEAR                  0.182034  1.000000 -0.092072  0.185800  0.057206
# story                 0.131797 -0.092072  1.000000  0.140587  0.114332
# SECTOR                0.149519  0.185800  0.140587  1.000000 -0.249102
# METHOD               -0.040094  0.057206  0.114332 -0.249102  1.000000
# DATA_SENSITIVITY     -0.153293 -0.024729  0.132565 -0.325916  0.155199
# source_name           0.075120  0.196888 -0.061801  0.058457  0.005725
#
#                   DATA_SENSITIVITY  source_name
# records_lost             -0.153293     0.075120
# YEAR                     -0.024729     0.196888
# story                     0.132565    -0.061801
# SECTOR                   -0.325916     0.058457
# METHOD                    0.155199     0.005725
# DATA_SENSITIVITY          1.000000    -0.200198
# source_name              -0.200198     1.000000

# %% [markdown]
# # Correlation graph

# %%
corr = df1.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
